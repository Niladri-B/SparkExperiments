# %%
#from pyspark import SparkContext
from pyspark.sql import Column, DataFrame, SparkSession, SQLContext, functions
from pyspark.sql.functions import *
from py4j.java_collections import MapConverter
from delta.tables import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("#######>>> Creating a table <<<#######")
data = spark.range(0,5)
data.write.format("delta").save("/tmp/delta-table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1676355210464254&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;#######&gt;&gt;&gt; Creating a table &lt;&lt;&lt;#######&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> data <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>range<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">5</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>data<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;delta&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;/tmp/delta-table&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">save</span><span class="ansi-blue-fg">(self, path, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    825</span>             self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    826</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 827</span><span class="ansi-red-fg">             </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    828</span>
# <span class="ansi-green-intense-fg ansi-bold">    829</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1304</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1305</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1306</span>
# <span class="ansi-green-intense-fg ansi-bold">   1307</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    132</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    133</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 134</span><span class="ansi-red-fg">                 </span>raise_from<span class="ansi-blue-fg">(</span>converted<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    135</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    136</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">raise_from</span><span class="ansi-blue-fg">(e)</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: dbfs:/tmp/delta-table already exists.;</div>

# %%
# %fs ls tmp/delta-table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/tmp/delta-table/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/tmp/delta-table/part-00000-1dbeb462-5c1b-46b1-8466-bf6dc031c64b-c000.snappy.parquet</td><td>part-00000-1dbeb462-5c1b-46b1-8466-bf6dc031c64b-c000.snappy.parquet</td><td>310</td></tr><tr><td>dbfs:/tmp/delta-table/part-00000-ab6d9737-d528-40f1-bb06-cf3181716e2c-c000.snappy.parquet</td><td>part-00000-ab6d9737-d528-40f1-bb06-cf3181716e2c-c000.snappy.parquet</td><td>310</td></tr><tr><td>dbfs:/tmp/delta-table/part-00001-0bebe877-3093-4df5-930a-b77ac0161585-c000.snappy.parquet</td><td>part-00001-0bebe877-3093-4df5-930a-b77ac0161585-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00001-3cce144d-a788-4f69-9e81-70d96579d59a-c000.snappy.parquet</td><td>part-00001-3cce144d-a788-4f69-9e81-70d96579d59a-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00003-0d9bfd89-1a12-4f69-8a83-5f56f41a65b9-c000.snappy.parquet</td><td>part-00003-0d9bfd89-1a12-4f69-8a83-5f56f41a65b9-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00003-4ea8c4c0-1d8b-4c0d-837a-ffea92dcdf18-c000.snappy.parquet</td><td>part-00003-4ea8c4c0-1d8b-4c0d-837a-ffea92dcdf18-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00004-50b062ef-25d5-482c-ae6e-1ba0560e9832-c000.snappy.parquet</td><td>part-00004-50b062ef-25d5-482c-ae6e-1ba0560e9832-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00004-8e453707-6006-4351-9bc8-2410c08cc6c9-c000.snappy.parquet</td><td>part-00004-8e453707-6006-4351-9bc8-2410c08cc6c9-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00006-0fe6361c-8499-45d1-b5b3-3fc0fce4d224-c000.snappy.parquet</td><td>part-00006-0fe6361c-8499-45d1-b5b3-3fc0fce4d224-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00006-44ee50c6-7cc4-4afa-a139-1b71e00170b1-c000.snappy.parquet</td><td>part-00006-44ee50c6-7cc4-4afa-a139-1b71e00170b1-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00007-c9351e91-8061-44dd-a4d9-9b98d5e6eaec-c000.snappy.parquet</td><td>part-00007-c9351e91-8061-44dd-a4d9-9b98d5e6eaec-c000.snappy.parquet</td><td>483</td></tr><tr><td>dbfs:/tmp/delta-table/part-00007-ea1006f1-7e63-4014-b6a7-1fc37e3c1ebd-c000.snappy.parquet</td><td>part-00007-ea1006f1-7e63-4014-b6a7-1fc37e3c1ebd-c000.snappy.parquet</td><td>483</td></tr></tbody></table></div>

# %%
# %fs ls tmp/delta-table/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/tmp/delta-table/_delta_log/.s3-optimization-0</td><td>.s3-optimization-0</td><td>0</td></tr><tr><td>dbfs:/tmp/delta-table/_delta_log/.s3-optimization-1</td><td>.s3-optimization-1</td><td>0</td></tr><tr><td>dbfs:/tmp/delta-table/_delta_log/.s3-optimization-2</td><td>.s3-optimization-2</td><td>0</td></tr><tr><td>dbfs:/tmp/delta-table/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>89</td></tr><tr><td>dbfs:/tmp/delta-table/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>2391</td></tr><tr><td>dbfs:/tmp/delta-table/_delta_log/00000000000000000001.crc</td><td>00000000000000000001.crc</td><td>90</td></tr><tr><td>dbfs:/tmp/delta-table/_delta_log/00000000000000000001.json</td><td>00000000000000000001.json</td><td>2048</td></tr></tbody></table></div>

# %%
#To download file go here: https://community.cloud.databricks.com/dbfs/tmp/delta-table/_delta_log/00000000000000000000.json?o=2296553551556281#

jsonMeta = spark.read.format("json").option("multiline","true").load("/tmp/delta-table/_delta_log/00000000000000000000.json")
display(jsonMeta)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>commitInfo</th></tr></thead><tbody><tr><td>List(0824-122130-shtik661, true, WriteSerializable, List(1676355210464249), WRITE, List(6, 2725, 5), List(ErrorIfExists, []), 1598274053561, 4611245696866562, niladri.banerjee@godtlevert.no)</td></tr></tbody></table></div>

# %%
# %scala
val mdf = spark.read.option("multiline", "false").json("/tmp/delta-table/_delta_log/00000000000000000000.json")
display(mdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>metaData</th><th>protocol</th></tr></thead><tbody><tr><td>null</td><td>List(0824-122130-shtik661, true, WriteSerializable, List(1676355210464249), WRITE, List(6, 2725, 5), List(ErrorIfExists, []), 1598274053561, 4611245696866562, niladri.banerjee@godtlevert.no)</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>List(1, 2)</td></tr><tr><td>null</td><td>null</td><td>List(1598274051720, List(parquet), aeb89b05-bfc8-4d97-be51-c3a807ea3231, List(), {"type":"struct","fields":[{"name":"id","type":"long","nullable":true,"metadata":{}}]})</td><td>null</td></tr><tr><td>List(true, 1598274054000, part-00000-ab6d9737-d528-40f1-bb06-cf3181716e2c-c000.snappy.parquet, 310, {"numRecords":0,"minValues":{},"maxValues":{},"nullCount":{}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1598274054000, part-00001-3cce144d-a788-4f69-9e81-70d96579d59a-c000.snappy.parquet, 483, {"numRecords":1,"minValues":{"id":0},"maxValues":{"id":0},"nullCount":{"id":0}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1598274054000, part-00003-4ea8c4c0-1d8b-4c0d-837a-ffea92dcdf18-c000.snappy.parquet, 483, {"numRecords":1,"minValues":{"id":1},"maxValues":{"id":1},"nullCount":{"id":0}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1598274054000, part-00004-50b062ef-25d5-482c-ae6e-1ba0560e9832-c000.snappy.parquet, 483, {"numRecords":1,"minValues":{"id":2},"maxValues":{"id":2},"nullCount":{"id":0}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1598274054000, part-00006-44ee50c6-7cc4-4afa-a139-1b71e00170b1-c000.snappy.parquet, 483, {"numRecords":1,"minValues":{"id":3},"maxValues":{"id":3},"nullCount":{"id":0}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1598274054000, part-00007-c9351e91-8061-44dd-a4d9-9b98d5e6eaec-c000.snappy.parquet, 483, {"numRecords":1,"minValues":{"id":4},"maxValues":{"id":4},"nullCount":{"id":0}})</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
print("#######>>> Reading the table <<<#######")
df = spark.read.format("delta").load("/tmp/delta-table")
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">#######&gt;&gt;&gt; Reading the table &lt;&lt;&lt;#######
# +---+
#  id|
# +---+
#   5|
#   0|
#   6|
#   1|
#   2|
#   7|
#   8|
#   3|
#   4|
#   9|
# +---+
#
# </div>

# %%
display(df)  #id is default name given, all dataframes have named columns in Spark
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>5</td></tr><tr><td>0</td></tr><tr><td>6</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>9</td></tr></tbody></table></div>

# %%
print("#######>>> Updating the table <<<#######")
data2 = spark.range(5,10)
appndedDf = df.union(data2)
appndedDf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.count()#Row count increased from 5 to 10 to 15 (over 3 runs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 15</div>

# %%
#df.show()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>5</td></tr><tr><td>0</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>1</td></tr><tr><td>6</td></tr><tr><td>2</td></tr><tr><td>7</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>3</td></tr><tr><td>8</td></tr><tr><td>4</td></tr><tr><td>9</td></tr><tr><td>9</td></tr></tbody></table></div>

# %%
#Optimise significantly improves read and execution times of Delta Tables (5-10X)
display(spark.sql("DROP TABLE  IF EXISTS df"))

display(spark.sql("CREATE TABLE df USING DELTA LOCATION '/tmp/delta-table/'"))

display(spark.sql("OPTIMIZE df"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>null</td><td>List(1, 18, List(560, 560, 560.0, 1, 560), List(310, 483, 454.0, 18, 8175), 1, null, 1)</td></tr></tbody></table></div>

# %%
display(df) #~1.6s vs 5s on non-optimised delta table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>5</td></tr><tr><td>0</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>1</td></tr><tr><td>6</td></tr><tr><td>2</td></tr><tr><td>7</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>3</td></tr><tr><td>8</td></tr><tr><td>4</td></tr><tr><td>9</td></tr><tr><td>9</td></tr></tbody></table></div>

# %%
# %sql

DESCRIBE HISTORY '/tmp/delta-table/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th></tr></thead><tbody><tr><td>3</td><td>2020-08-25T08:48:52.000+0000</td><td>4611245696866562</td><td>niladri.banerjee@godtlevert.no</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> false)</td><td>null</td><td>List(1676355210464249)</td><td>0825-083423-puts120</td><td>2</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 18, numRemovedBytes -> 8175, p25FileSize -> 560, minFileSize -> 560, numAddedFiles -> 1, maxFileSize -> 560, p75FileSize -> 560, p50FileSize -> 560, numAddedBytes -> 560)</td></tr><tr><td>2</td><td>2020-08-25T08:43:54.000+0000</td><td>4611245696866562</td><td>niladri.banerjee@godtlevert.no</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(1676355210464249)</td><td>0825-083423-puts120</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 6, numOutputBytes -> 2725, numOutputRows -> 5)</td></tr><tr><td>1</td><td>2020-08-24T14:49:23.000+0000</td><td>4611245696866562</td><td>niladri.banerjee@godtlevert.no</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(1676355210464249)</td><td>0824-122130-shtik661</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 6, numOutputBytes -> 2725, numOutputRows -> 5)</td></tr><tr><td>0</td><td>2020-08-24T13:00:54.000+0000</td><td>4611245696866562</td><td>niladri.banerjee@godtlevert.no</td><td>WRITE</td><td>Map(mode -> ErrorIfExists, partitionBy -> [])</td><td>null</td><td>List(1676355210464249)</td><td>0824-122130-shtik661</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 6, numOutputBytes -> 2725, numOutputRows -> 5)</td></tr></tbody></table></div>

# %%
df_old = spark.read.format("delta").option("versionAsOf",0).load("/tmp/delta-table")
#df_old.show()
display(df_old)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr></tbody></table></div>
